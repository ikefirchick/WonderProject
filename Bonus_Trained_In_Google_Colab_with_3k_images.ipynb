# %%
from google.colab import drive # layout for google drive

drive.mount('/content/drive/', force_remount=True) # mounting point for google drive

# %%
from __future__ import print_function

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import cv2

from keras.models import Sequential

from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dense

from keras.utils import plot_model
from keras.utils import np_utils

from keras.callbacks import EarlyStopping

################################################################################
# Read the data
################################################################################
raw_data = pd.read_csv('/content/drive/My Drive/Wonderobe/DATASET_3k_JPG/labels.csv')

print(raw_data)

print(" >>> ", len(raw_data))

raw_pic = []
raw_lbl = []

for i in range(0, len(raw_data)):
#for i in range(0, len(raw_data) - 1):
    item = raw_data.iloc[i]
    
    img_file = '/content/drive/My Drive/Wonderobe/DATASET_3k_JPG/train/' + item['fname']
    #print(img_file)
    img = cv2.imread(img_file)

    y = 0
    h = 160
    x = int((646 - 640) / 2)
    w = 640 
    
    crop_img = img[y:y+h, x:x+w]
    crop_img = cv2.cvtColor(crop_img, cv2.COLOR_BGR2RGB)
    raw_pic.append(crop_img)
    
    lbl = item['label']
    #print(lbl)
    lbl_in_np = np.fromstring(lbl[1:-1], dtype=int, sep=',')
    #print(lbl_in_np)
    
    raw_lbl.append(lbl_in_np)
    
#--- process image -------------------------------------------------------------
train_img = np.array(raw_pic)
print(" >>> train_img.shape = ", train_img.shape)
train_img_size_h = train_img.shape[1]
train_img_size_w = train_img.shape[2]
print(" >>> h = ", train_img_size_h)
print(" >>> w = ", train_img_size_w)

# train_img = train_img.astype('float32') 
train_img = train_img / 255.0

#--- preprocess label ----------------------------------------------------------
train_lbl = np.array(raw_lbl)
print(" >>> train_ans.shape = ", train_lbl.shape)

################################################################################
# Build the model
################################################################################
input_shape_img = (train_img.shape[1], train_img.shape[2], 3) ##########sssssssssssssssssssssss
batch_size = 32
num_epochs = 100 # WAS 100
num_classes = 10
conv_size = 32

print(" >>> input_shape_img = ", input_shape_img)

#-------------------------------------------------------------------------------
model = Sequential()

model.add(Conv2D(conv_size, (3, 3), activation='relu', padding='same', input_shape=input_shape_img)) 
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(conv_size, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(conv_size, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(conv_size, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(GlobalAveragePooling2D())

model.add(Dense(256, activation='sigmoid'))
model.add(Dense(128, activation='sigmoid'))
model.add(Dense(64, activation='sigmoid'))
model.add(Dense(num_classes, activation='sigmoid'))

#-------------------------------------------------------------------------------
model.compile(loss='binary_crossentropy',
                        optimizer='adam',
                        metrics=['accuracy'])
              
model.summary()

################################################################################
# Train the model
################################################################################
print(" >>> CNN Model Training ... \n")

early_stop = EarlyStopping(monitor='loss', patience=50, verbose=1)
                                            
history = model.fit(train_img, train_lbl,
                        batch_size=batch_size,
                        epochs=num_epochs,
                        verbose=1,
                        validation_split=0.1,
                        callbacks=[early_stop])

################################################################################
# Check the history
################################################################################
plt.figure(facecolor='white')

# accuracy ---------------------------------------------------------------------
ax1 = plt.subplot(2,1,1)

plt.plot([x * 100 for x in history.history['accuracy']], label="accuracy", color="blue")
plt.plot([x * 100 for x in history.history['val_accuracy']], label="val_accuracy", color="red")

plt.title('Accuracy History')
plt.ylabel('accuracy')
# plt.xlabel('epoch')

plt.legend(['train', 'valid'], loc='lower right')

plt.ylim(0, 1)
plt.xticks(np.arange(0, num_epochs + 1, 5))
plt.yticks(np.arange(0, 100.1, 10))
ax1.yaxis.set_major_formatter(plt.FuncFormatter('{:.0f}%'.format))
plt.grid()

# loss -------------------------------------------------------------------------
plt.subplot(2,1,2)

plt.plot(history.history['loss'], label="loss", color="blue")
plt.plot(history.history['val_loss'], label="val_loss", color="red")

plt.title('Loss History')
plt.ylabel('loss')
plt.xlabel('epoch')

plt.legend(['train', 'valid'], loc='lower left')

plt.ylim(0)
plt.xticks(np.arange(0, num_epochs + 1, 5))
plt.grid()
plt.show()
# Out:
# Using TensorFlow backend.
#       index     fname  ... real_int             real_str
# 0         0  0000.jpg  ...     3, 8           Dress, Bag
# 1         1  0001.jpg  ...     3, 9    Dress, Ankle boot
# 2         2  0002.jpg  ...     1, 8         Trouser, Bag
# 3         3  0003.jpg  ...     6, 6         Shirt, Shirt
# 4         4  0004.jpg  ...     7, 9  Sneaker, Ankle boot
# ...     ...       ...  ...      ...                  ...
# 2995   2995  2995.jpg  ...        7              Sneaker
# 2996   2996  2996.jpg  ...        4                 Coat
# 2997   2997  2997.jpg  ...        1              Trouser
# 2998   2998  2998.jpg  ...        1              Trouser
# 2999   2999  2999.jpg  ...        9           Ankle boot
#
# [3000 rows x 5 columns]
#  >>>  3000
#  >>> train_img.shape =  (3000, 160, 493, 3)
#  >>> h =  160
#  >>> w =  493
#  >>> train_ans.shape =  (3000, 10)
#  >>> input_shape_img =  (160, 493, 3)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 160, 493, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 80, 246, 32)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 80, 246, 32)       9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 40, 123, 32)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 40, 123, 32)       9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 20, 61, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 20, 61, 32)        9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 10, 30, 32)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               8448
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                650
# =================================================================
# Total params: 78,890
# Trainable params: 78,890
# Non-trainable params: 0
# _________________________________________________________________
#  >>> CNN Model Training ...
#
# Train on 2700 samples, validate on 300 samples
# Epoch 1/100
# 2700/2700 [==============================] - 18s 7ms/step - loss: 0.4601 - accuracy: 0.8077 - val_loss: 0.3289 - val_accuracy: 0.9000
# Epoch 2/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3865 - accuracy: 0.8668 - val_loss: 0.3255 - val_accuracy: 0.9000
# Epoch 3/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3866 - accuracy: 0.8668 - val_loss: 0.3261 - val_accuracy: 0.9000
# Epoch 4/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3867 - accuracy: 0.8668 - val_loss: 0.3254 - val_accuracy: 0.9000
# Epoch 5/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3868 - accuracy: 0.8668 - val_loss: 0.3247 - val_accuracy: 0.9000
# Epoch 6/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3866 - accuracy: 0.8668 - val_loss: 0.3251 - val_accuracy: 0.9000
# Epoch 7/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3868 - accuracy: 0.8668 - val_loss: 0.3250 - val_accuracy: 0.9000
# Epoch 8/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3867 - accuracy: 0.8668 - val_loss: 0.3242 - val_accuracy: 0.9000
# Epoch 9/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3866 - accuracy: 0.8668 - val_loss: 0.3267 - val_accuracy: 0.9000
# Epoch 10/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3868 - accuracy: 0.8668 - val_loss: 0.3249 - val_accuracy: 0.9000
# Epoch 11/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3866 - accuracy: 0.8668 - val_loss: 0.3255 - val_accuracy: 0.9000
# Epoch 12/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3866 - accuracy: 0.8668 - val_loss: 0.3258 - val_accuracy: 0.9000
# Epoch 13/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3868 - accuracy: 0.8668 - val_loss: 0.3251 - val_accuracy: 0.9000
# Epoch 14/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3869 - accuracy: 0.8668 - val_loss: 0.3243 - val_accuracy: 0.9000
# Epoch 15/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3866 - accuracy: 0.8668 - val_loss: 0.3255 - val_accuracy: 0.9000
# Epoch 16/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3866 - accuracy: 0.8668 - val_loss: 0.3261 - val_accuracy: 0.9000
# Epoch 17/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3868 - accuracy: 0.8668 - val_loss: 0.3247 - val_accuracy: 0.9000
# Epoch 18/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3867 - accuracy: 0.8668 - val_loss: 0.3250 - val_accuracy: 0.9000
# Epoch 19/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3869 - accuracy: 0.8668 - val_loss: 0.3251 - val_accuracy: 0.9000
# Epoch 20/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3865 - accuracy: 0.8668 - val_loss: 0.3248 - val_accuracy: 0.9000
# Epoch 21/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3865 - accuracy: 0.8668 - val_loss: 0.3253 - val_accuracy: 0.9000
# Epoch 22/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3828 - accuracy: 0.8668 - val_loss: 0.3207 - val_accuracy: 0.9000
# Epoch 23/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3778 - accuracy: 0.8668 - val_loss: 0.3208 - val_accuracy: 0.9000
# Epoch 24/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3737 - accuracy: 0.8668 - val_loss: 0.3110 - val_accuracy: 0.9000
# Epoch 25/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3706 - accuracy: 0.8668 - val_loss: 0.3081 - val_accuracy: 0.9000
# Epoch 26/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3674 - accuracy: 0.8668 - val_loss: 0.3027 - val_accuracy: 0.9000
# Epoch 27/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3638 - accuracy: 0.8693 - val_loss: 0.3075 - val_accuracy: 0.8997
# Epoch 28/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3680 - accuracy: 0.8673 - val_loss: 0.3019 - val_accuracy: 0.9000
# Epoch 29/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3636 - accuracy: 0.8668 - val_loss: 0.2957 - val_accuracy: 0.9000
# Epoch 30/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3585 - accuracy: 0.8668 - val_loss: 0.2883 - val_accuracy: 0.9000
# Epoch 31/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3516 - accuracy: 0.8669 - val_loss: 0.2778 - val_accuracy: 0.9027
# Epoch 32/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3482 - accuracy: 0.8673 - val_loss: 0.2755 - val_accuracy: 0.9057
# Epoch 33/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3394 - accuracy: 0.8723 - val_loss: 0.2635 - val_accuracy: 0.9093
# Epoch 34/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3280 - accuracy: 0.8741 - val_loss: 0.2495 - val_accuracy: 0.9143
# Epoch 35/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.3108 - accuracy: 0.8809 - val_loss: 0.2319 - val_accuracy: 0.9163
# Epoch 36/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.2954 - accuracy: 0.8864 - val_loss: 0.2209 - val_accuracy: 0.9183
# Epoch 37/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.2798 - accuracy: 0.8919 - val_loss: 0.2046 - val_accuracy: 0.9350
# Epoch 38/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.2693 - accuracy: 0.8969 - val_loss: 0.1976 - val_accuracy: 0.9317
# Epoch 39/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.2571 - accuracy: 0.9014 - val_loss: 0.1831 - val_accuracy: 0.9437
# Epoch 40/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.2461 - accuracy: 0.9065 - val_loss: 0.1759 - val_accuracy: 0.9420
# Epoch 41/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.2353 - accuracy: 0.9108 - val_loss: 0.1684 - val_accuracy: 0.9467
# Epoch 42/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.2234 - accuracy: 0.9168 - val_loss: 0.1505 - val_accuracy: 0.9483
# Epoch 43/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.2084 - accuracy: 0.9217 - val_loss: 0.1373 - val_accuracy: 0.9557
# Epoch 44/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.1962 - accuracy: 0.9281 - val_loss: 0.1239 - val_accuracy: 0.9590
# Epoch 45/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.1854 - accuracy: 0.9330 - val_loss: 0.1160 - val_accuracy: 0.9657
# Epoch 46/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.1781 - accuracy: 0.9349 - val_loss: 0.1131 - val_accuracy: 0.9640
# Epoch 47/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.1707 - accuracy: 0.9386 - val_loss: 0.1092 - val_accuracy: 0.9663
# Epoch 48/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.1603 - accuracy: 0.9426 - val_loss: 0.1009 - val_accuracy: 0.9680
# Epoch 49/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.1558 - accuracy: 0.9438 - val_loss: 0.0922 - val_accuracy: 0.9700
# Epoch 50/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.1480 - accuracy: 0.9465 - val_loss: 0.0834 - val_accuracy: 0.9797
# Epoch 51/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.1402 - accuracy: 0.9507 - val_loss: 0.0836 - val_accuracy: 0.9793
# Epoch 52/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.1353 - accuracy: 0.9524 - val_loss: 0.0779 - val_accuracy: 0.9740
# Epoch 53/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.1304 - accuracy: 0.9537 - val_loss: 0.0674 - val_accuracy: 0.9823
# Epoch 54/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.1253 - accuracy: 0.9561 - val_loss: 0.0647 - val_accuracy: 0.9843
# Epoch 55/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.1174 - accuracy: 0.9593 - val_loss: 0.0564 - val_accuracy: 0.9837
# Epoch 56/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.1116 - accuracy: 0.9616 - val_loss: 0.0518 - val_accuracy: 0.9870
# Epoch 57/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.1083 - accuracy: 0.9626 - val_loss: 0.0527 - val_accuracy: 0.9893
# Epoch 58/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.1054 - accuracy: 0.9634 - val_loss: 0.0486 - val_accuracy: 0.9890
# Epoch 59/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0974 - accuracy: 0.9669 - val_loss: 0.0385 - val_accuracy: 0.9933
# Epoch 60/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0919 - accuracy: 0.9687 - val_loss: 0.0343 - val_accuracy: 0.9973
# Epoch 61/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0904 - accuracy: 0.9690 - val_loss: 0.0368 - val_accuracy: 0.9940
# Epoch 62/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0861 - accuracy: 0.9712 - val_loss: 0.0276 - val_accuracy: 0.9993
# Epoch 63/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0811 - accuracy: 0.9734 - val_loss: 0.0240 - val_accuracy: 1.0000
# Epoch 64/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0785 - accuracy: 0.9739 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 65/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0746 - accuracy: 0.9763 - val_loss: 0.0211 - val_accuracy: 1.0000
# Epoch 66/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0693 - accuracy: 0.9778 - val_loss: 0.0212 - val_accuracy: 0.9963
# Epoch 67/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0672 - accuracy: 0.9774 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 68/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0658 - accuracy: 0.9781 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 69/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0617 - accuracy: 0.9801 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 70/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0598 - accuracy: 0.9800 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 71/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0593 - accuracy: 0.9809 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 72/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0546 - accuracy: 0.9818 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 73/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0548 - accuracy: 0.9809 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 74/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0520 - accuracy: 0.9826 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 75/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0489 - accuracy: 0.9840 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 76/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0495 - accuracy: 0.9836 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 77/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0483 - accuracy: 0.9838 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 78/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0500 - accuracy: 0.9827 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 79/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0441 - accuracy: 0.9851 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 80/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0410 - accuracy: 0.9865 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 81/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0404 - accuracy: 0.9870 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 82/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0400 - accuracy: 0.9859 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 83/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0373 - accuracy: 0.9887 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 84/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0374 - accuracy: 0.9883 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 85/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0340 - accuracy: 0.9891 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 86/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0345 - accuracy: 0.9892 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 87/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0324 - accuracy: 0.9899 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 88/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0312 - accuracy: 0.9903 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 89/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0303 - accuracy: 0.9907 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 90/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0285 - accuracy: 0.9919 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 91/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0271 - accuracy: 0.9918 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 92/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0327 - accuracy: 0.9891 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 93/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0268 - accuracy: 0.9916 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 94/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0246 - accuracy: 0.9929 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 95/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0252 - accuracy: 0.9927 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 96/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0242 - accuracy: 0.9931 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 97/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0197 - accuracy: 0.9950 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 98/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0186 - accuracy: 0.9953 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 99/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0203 - accuracy: 0.9943 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 100/100
# 2700/2700 [==============================] - 11s 4ms/step - loss: 0.0188 - accuracy: 0.9947 - val_loss: 0.0020 - val_accuracy: 1.0000

# %%
################################################################################
# Check the test dataset
################################################################################
t_data = pd.read_csv('/content/drive/My Drive/Wonderobe/DATASET_300_JPG_test/labels_test.csv')

# print(raw_data)

# print(" >>> ", len(raw_data))

t_pic = []
t_lbl = []
t_int = []
t_str = []

for i in range(0, len(t_data)):
    item = t_data.iloc[i]
    
    img_file = '/content/drive/My Drive/Wonderobe/DATASET_300_JPG_test/test/' + item['fname']
#     print(img_file)
    img = cv2.imread(img_file)
    
    y = 0
    h = 160
    x = int((646 - 640) / 2)
    w = 640 
    
    crop_img = img[y:y+h, x:x+w]
    crop_img = cv2.cvtColor(crop_img, cv2.COLOR_BGR2RGB)
    t_pic.append(crop_img)
    
    lbl = item['label']
#     print(lbl)
    lbl_in_np = np.fromstring(lbl[1:-1], dtype=int, sep=',')
#     print(lbl_in_np)
    
    t_lbl.append(lbl_in_np)
    
    t_int.append(item['real_int'])
    t_str.append(item['real_str'])
    
#--- process image -------------------------------------------------------------
test_img = np.array(t_pic)
# print(" >>> test_img.shape = ", test_img.shape)

# test_img = test_img.astype('float32') 
test_img = test_img / 255.0

#--- preprocess label ----------------------------------------------------------
test_lbl = np.array(t_lbl)
# print(" >>> test_lbl.shape = ", test_lbl.shape)

#--- evaluate ------------------------------------------------------------------
acc = model.evaluate(test_img, test_lbl, verbose=1)[1]
print(" >>> Accuracy on test data = ", round(acc, 3))
# Out:
# 300/300 [==============================] - 1s 2ms/step
#  >>> Accuracy on test data =  0.983
